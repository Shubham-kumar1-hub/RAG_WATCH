# %%
import pandas as pd

# %%
df = pd.read_csv("eval_run_topk8.csv")

# %%
df
# Out:
#                                           user_input  \
# 0   What is self-attention in the Transformer model?
# 1  Can you explain, from the perspective of an NL...
# 2  How many NVIDIA P100 GPUs we use and how long ...
# 3  Considering the discussion of self‑attention m...
# 4  How transformer architecture differ from encod...
# 5  How does the self‑attention (intra‑attention) ...
#
#                                   retrieved_contexts  \
# 0  ['language modeling tasks [34].\nTo the best o...
# 1  ['3 Model Architecture\nMost competitive neura...
# 2  ['target tokens.\n5.2 Hardware and Schedule\nW...
# 3  ['based solely on attention mechanisms, dispen...
# 4  ['Figure 1: The Transformer - model architectu...
# 5  ['7 Conclusion\nIn this work, we presented the...
#
#                                             response  \
# 0  Self‑attention is the core mechanism used by t...
# 1  The decoder works **auto‑regressively**, which...
# ...

# %%
row
# Out:
#                                           user_input  \
# 5  How does the self‑attention (intra‑attention) ...
#
#                                   retrieved_contexts response  \
# 5  ['7 Conclusion\nIn this work, we presented the...      NaN
#
#                                            reference  faithfulness  \
# 5  In the Transformer, self‑attention (also calle...           NaN
#
#    answer_relevancy  llm_context_precision_with_reference  context_recall
# 5               0.0                              0.747024        0.666667

# %%
row = df[df["user_input"].str.contains("intra‑attention", na=False)]
print(row["response"].values[0])
# Out:
# nan

# %%
print(row["response"])
# Out:
# 5    NaN
# Name: response, dtype: object
